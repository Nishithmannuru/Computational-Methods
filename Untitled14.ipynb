# %%
import pandas as pd
data= pd.read_csv("all_sentiment_shuffled.txt", sep="\t", encoding="utf-8")
data.head()
def read_documents(doc_file):
    docs = []
    labels = []
    label=[]
    with open(doc_file, encoding='utf-8') as f:
        for line in f:
            words = line.strip().split()
            docs.append(words[3:])
            labels.append(words[1])
        for i in range(0,len(labels)):
          if labels[i] == 'pos':
              label.append(1)
          elif labels[i] == 'neg':
             label.append(0)
        
    return docs, label

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data)
print(vectorizer.get_feature_names())
print(X.toarray())


# Get the text categories
text_categories = data.target_names

print("We have {} unique classes".format(len(train_labels)))
print("We have {} training samples".format(len(train_docs)))
print("We have {} test samples".format(len(eval_docs)))

from collections import Counter  
with open('all_sentiment_shuffled.txt', 'r') as file:
    text = file.read()      
example_documents = [text.split()]
  
freqs1 = Counter()
for doc in example_documents:
    for w in doc:
        freqs1[w] += 1
print(freqs1)
df=pd.DataFrame(freqs1.keys(),freqs1.values())

all_docs, all_labels = read_documents('all_sentiment_shuffled.txt')
all_labels=pd.DataFrame(all_labels)
all_docs=pd.DataFrame(all_docs)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(all_docs, all_labels, test_size=0.2,  random_state=1)

#lab=train_nb(X_train,y_train)
#encoder = preprocessing.LabelEncoder()
#y_train = encoder.fit_transform(y_train)
#y_test = encoder.fit_transform(y_test)

from sklearn.naive_bayes import GaussianNB
naive_bayes = GaussianNB()
naive_bayes.fit(X_train, y_train) 
predictions = naive_bayes.predict(X_test)
yhat_prob = model.predict_proba(X_test)
print('Predicted Probabilities: ', yhat_prob)
# make a classification prediction
print('Predicted Class: ', y_test)
print('Truth: y=%d' % y_test)
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, predictions))

#predicted labels

testing_predictions = []
for i in range(len(X_test)):
    if predictions[i] == 1:
        testing_predictions.append('pos') 
    else:
        testing_predictions.append('neg')
# Out:
# Counter({'the': 82020, '.': 76027, ',': 66753, 'and': 43219, 'to': 40614, 'i': 39477, 'a': 38786, 'of': 33753, 'it': 30093, 'is': 27868, 'this': 23634, 'in': 20197, 'that': 18619, '"': 16347, 'for': 15822, 'you': 14089, 'with': 12976, "'s": 12642, 'was': 11481, 'on': 11409, 'not': 10563, 'have': 10471, 'but': 10440, 'as': 9939, 'my': 9182, 'are': 8917, "n't": 8888, ')': 8094, '(': 7815, 'be': 7188, '!': 7085, 'one': 6619, 'all': 6074, 'pos': 6000, 'neg': 5914, 'so': 5882, 'if': 5878, 'do': 5770, 'from': 5644, 'they': 5609, 'at': 5605, 'camera': 5475, 'or': 5457, '-': 5115, 'like': 5064, 'an': 4965, 'just': 4690, 'has': 4599, 'very': 4543, 'he': 4512, 'book': 4500, 'about': 4447, 'by': 4443, 'would': 4441, 'out': 4369, 'more': 4270, 'his': 4258, 'there': 4185, 'me': 4097, 'when': 4094, 'can': 4078, 'what': 3987, 'good': 3864, 'will': 3746, 'had': 3709, 'music': 3604, 'get': 3592, 'no': 3574, 'great': 3538, 'some': 3517, 'your': 3449, 'only': 3418, 'up': 3394, 'time': 3320, 'software':
# ...

# %%
(l)
